# %% [markdown]
# # All the Lifecycle In a Data SCience Projects

# %% [raw]
# # Data Analysis
# # Feature Engineering
# # Feature Selection
# # Model Bulding
# # Model Deployment

# %% [markdown]
# # Data Analysis

# %%
# Main aim is to understand more about data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Display all the columns of the dataframe

pd.pandas.set_option('display.max_columns',None)

# %%
df = pd.read_csv('train.csv')

# %%
#For the first 5 record of dataset
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
## Print the shape of the data set with raw and columns
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# # In Data Analysis We Will Analyze To find out the below stuff

# %% [raw]
# # 1.Missing values
# # 2.All the Numerical Variables
# # 3.Distribution of Numerical Variales
# # 4.Categorical Variables
# # 5.Cardibality of Categorical Variable
# # 6.Outliers
# # 7.Relationship Between independent and dependent feature(Sale price)

# %% [markdown]
# # Missing values

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# Here i will check the percentage of NaN values in each feature
# Step 1- Make the list of feature which has missing values
# Step 2- Print the feature name and the percentage of missing values

# %%
## Step 1
features_with_na = [features for features in df.columns if df[features].isnull().sum()>1]

# %%
features_with_na
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
## Step 2
for feature in features_with_na:
    print(feature,np.round(df[feature].isnull().sum().mean(),4),'% missing values')
# Out:
# LotFrontage 259.0 % missing values
# Alley 1369.0 % missing values
# MasVnrType 872.0 % missing values
# MasVnrArea 8.0 % missing values
# BsmtQual 37.0 % missing values
# BsmtCond 37.0 % missing values
# BsmtExposure 38.0 % missing values
# BsmtFinType1 37.0 % missing values
# BsmtFinType2 38.0 % missing values
# FireplaceQu 690.0 % missing values
# GarageType 81.0 % missing values
# GarageYrBlt 81.0 % missing values
# GarageFinish 81.0 % missing values
# GarageQual 81.0 % missing values
# GarageCond 81.0 % missing values
# PoolQC 1453.0 % missing values
# Fence 1179.0 % missing values
# MiscFeature 1406.0 % missing values

# %% [markdown]
# #### Since there are many missing values we need to find out the relationship between missing value and sales Price

# %%
for feature in features_with_na:
    data = df.copy()
    
    #Lets make a variable that indicates 1 if observation was missing or zero 
    #Whichever having nan value i replace with 1 and else is zero
    data[feature] = np.where(data[feature].isnull(),1,0)
    
    #Lets calculate the mean saleprice where the information is missing or present
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# #### Here with the relationship between the missing values and dependent variable is clearly visible.so we need to replace these nan values with something meaningful which we will do in Feature Engineering

# %%
print("ID of Houses {}".format(len(df.Id)))
# Out:
# ID of Houses 1460

# %% [markdown]
# # Numerical Variables

# %%
#List the numeric variables 
numerical_feature = [feature for feature in df.columns if df[feature].dtypes !='O']

# %%
print('number of numeric feature variables: ',len (numerical_feature))
# Out:
# number of numeric feature variables:  38

# %%
df[numerical_feature].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
#List of variable that conatin year information
year_feature = [feature for feature in numerical_feature if 'Yr' in feature or 'Year' in feature]

# %%
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in year_feature:
    print(feature,df[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
# I will check weather there is relation between year and sale price
df.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median of House Price')
plt.title("House price vs Yearsold")
# Out:
# Text(0.5, 1.0, 'House price vs Yearsold')

# %%
## Here we will compare the difference between All the years feature and sale price
for feature in year_feature:
    if feature != "YrSold":
        data = df.copy()
        
        data[feature]=data['YrSold']-data[feature]
        
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %%
## Numerical feature are basically 2 types 
## 1.Continuos variable and Disceare variables

discrete_feature =[feature for feature in numerical_feature if len(df[feature].unique())<25 and feature not in year_feature+['Id'] ]

# %%
print("Discreate variable counts: {}".format(len(discrete_feature)))
discrete_feature
# Out:
# Discreate variable counts: 17
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
df[discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
## Lets find the relationship between discrete and sale price

for feature in discrete_feature:
    data=df.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel("Sale Price")
    plt.title(feature)
    plt.show()

# %% [markdown]
# #### Contineous variable

# %%
contineous_feature =[feature for feature in numerical_feature if feature not in discrete_feature + year_feature+['Id'] ]

# %%
print("Contineous variable counts: {}".format(len(contineous_feature)))
contineous_feature
# Out:
# Contineous variable counts: 16
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
for feature in contineous_feature:
    data = df.copy()
    data[feature].hist(bins=35)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
## I will be using Logarithmatic Transformation
## Code to how to apply log normal distribution


for feature in contineous_feature:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]= np.log(data[feature])
        data['SalePrice']=np.log(data["SalePrice"])
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel("SalePrice")
        plt.title(feature)
        plt.show()

# %% [markdown]
# ## Outliers

# %%
for feature in contineous_feature:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# # Categorical Variables

# %%
categorical_feature = [feature for feature in df.columns if data[feature].dtypes=='O']

# %%
categorical_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
df[categorical_feature].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
for feature in categorical_feature:
    print("The feature is {} and number of categories are {}".format(feature,df[feature].unique()))
# Out:
# The feature is MSZoning and number of categories are ['RL' 'RM' 'C (all)' 'FV' 'RH']
# The feature is Street and number of categories are ['Pave' 'Grvl']
# The feature is Alley and number of categories are [nan 'Grvl' 'Pave']
# The feature is LotShape and number of categories are ['Reg' 'IR1' 'IR2' 'IR3']
# The feature is LandContour and number of categories are ['Lvl' 'Bnk' 'Low' 'HLS']
# The feature is Utilities and number of categories are ['AllPub' 'NoSeWa']
# The feature is LotConfig and number of categories are ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# The feature is LandSlope and number of categories are ['Gtl' 'Mod' 'Sev']
# The feature is Neighborhood and number of categories are ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# ...

# %%
for feature in categorical_feature:
    print("The feature is {} and number of categories are {}".format(feature,len(df[feature].unique())))
# Out:
# The feature is MSZoning and number of categories are 5
# The feature is Street and number of categories are 2
# The feature is Alley and number of categories are 3
# The feature is LotShape and number of categories are 4
# The feature is LandContour and number of categories are 4
# The feature is Utilities and number of categories are 2
# The feature is LotConfig and number of categories are 5
# The feature is LandSlope and number of categories are 3
# The feature is Neighborhood and number of categories are 25
# The feature is Condition1 and number of categories are 9
# The feature is Condition2 and number of categories are 8
# The feature is BldgType and number of categories are 5
# The feature is HouseStyle and number of categories are 8
# The feature is RoofStyle and number of categories are 6
# The feature is RoofMatl and number of categories are 8
# The feature is Exterior1st and number of categories are 15
# The feature is Exterior2nd and number of categories are 16
# ...

# %%
## Find the relationship between categorical variable and dependent variable

for feature in categorical_feature:
    data=df.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel("Sale Price")
    plt.title(feature)
    plt.show()

# %% [markdown]
# # Feature Engineering

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# Alwayes remember there way always be chance of data leakage so we need to split the data first and start apply feature
## Engineering

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df,df["SalePrice"],test_size=0.1,random_state=42)

# %%
x_train.shape , x_test.shape
# Out:
# ((1314, 81), (146, 81))

# %% [markdown]
# # Missing value

# %%
#Let us capture all the Nan values
## First lets handle categorical features which are missing
featutre_nan = [feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtypes=='O']

for feature in featutre_nan:
    print("{}: {}%missing values".format(feature,np.round(df[feature].isnull().mean(),4)))
# Out:
# Alley: 0.9377%missing values
# MasVnrType: 0.5973%missing values
# BsmtQual: 0.0253%missing values
# BsmtCond: 0.0253%missing values
# BsmtExposure: 0.026%missing values
# BsmtFinType1: 0.0253%missing values
# BsmtFinType2: 0.026%missing values
# FireplaceQu: 0.4726%missing values
# GarageType: 0.0555%missing values
# GarageFinish: 0.0555%missing values
# GarageQual: 0.0555%missing values
# GarageCond: 0.0555%missing values
# PoolQC: 0.9952%missing values
# Fence: 0.8075%missing values
# MiscFeature: 0.963%missing values

# %%
# Replace Nan value with new label
def replace_cat_feature(df,featutre_nan):
    data = df.copy()
    data[featutre_nan]=data[featutre_nan].fillna('Missing')
    return data

df = replace_cat_feature(df,featutre_nan)

df[featutre_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
## Now lets check for numerical variables the contains missing values
numerical_with_nan = [feature for feature in df.columns if df[feature].isnull().sum() > 1 and df[feature].dtype != 'O']

for feature in numerical_with_nan:
    print("{}: {}%missing values".format(feature,np.round(df[feature].isnull().mean(),4)))
# Out:
# LotFrontage: 0.1774%missing values
# MasVnrArea: 0.0055%missing values
# GarageYrBlt: 0.0555%missing values

# %%
# Replacing the numerical Missing value

for feature in numerical_with_nan:
    #I will replace it with median coz there is outliers
    median_value=df[feature].median()
    
    df[feature+'nan']=np.where(df[feature].isnull(),1,0)
    df[feature].fillna(median_value,inplace=True)
df[numerical_with_nan].isnull().sum()
# Out:
# C:\Users\SAGAR DABGAR\AppData\Local\Temp\ipykernel_18744\1503264993.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[feature].fillna(median_value,inplace=True)
# C:\Users\SAGAR DABGAR\AppData\Local\Temp\ipykernel_18744\1503264993.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
## Temporal variables (Date and time variables)

for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
    df[feature]=df['YrSold']-df[feature]

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %% [markdown]
# # Numerical variables

# %% [markdown]
# ## Since the numerical variables are skewed we will perform log normal distribution

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
import numpy as np

num_feature=['LotFrontage','LotArea','1stFlrSF','GrLivArea','SalePrice']

for feature in num_feature:
    df[feature]= np.log(df[feature])

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1   2          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2   3          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3   4          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4   5          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # Handling the Rare categorical feature
# # I will remove categorical variables that are present less than 1% of the obeservation

# %%
categorical_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in categorical_feature:
    temp = df.groupby(feature)['SalePrice'].count()/len(df)
    temp_df = temp[temp>0.01].index
    df[feature] = np.where(df[feature].isin(temp_df),df[feature],'Rare_var')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1   2          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2   3          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3   4          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4   5          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl     Rare_var      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

for feature in categorical_feature:
    df[feature + '_encoded'] = label_encoder.fit_transform(df[feature].astype(str))
    df.drop(feature, axis=1, inplace=True)
print(df.head())
# Out:
#    Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60     4.174387  9.041922            7            5          5
# 1   2          20     4.382027  9.169518            6            8         31
# 2   3          60     4.219508  9.328123            7            5          7
# 3   4          70     4.094345  9.164296            7            5         91
# 4   5          60     4.430817  9.565214            8            5          8
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0             5       196.0         706           0        150          856
# 1            31         0.0         978           0        284         1262
# 2             6       162.0         486           0        434          920
# 3            36         0.0         216           0        540          756
# 4             8       350.0         655           0        490         1145
#
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60     4.174387  9.041922            7            5          5
# 1   2          20     4.382027  9.169518            6            8         31
# 2   3          60     4.219508  9.328123            7            5          7
# 3   4          70     4.094345  9.164296            7            5         91
# 4   5          60     4.430817  9.565214            8            5          8
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0             5       196.0         706           0        150          856
# 1            31         0.0         978           0        284         1262
# 2             6       162.0         486           0        434          920
# 3            36         0.0         216           0        540          756
# 4             8       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# ## Feature scaling

# %%
feature_scale = [feature for feature in df.columns if feature not in ['ID','SalePrice']]
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df[feature_scale])
# Out:
# MinMaxScaler()

# %%
scaler.transform(df[feature_scale])
# Out:
# array([[0.00000000e+00, 2.35294118e-01, 4.18208121e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 5.00000000e-01],
#        [6.85400960e-04, 0.00000000e+00, 4.95063747e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 5.00000000e-01],
#        [1.37080192e-03, 2.35294118e-01, 4.34908997e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 5.00000000e-01],
#        ...,
#        [9.98629198e-01, 2.94117647e-01, 4.23859223e-01, ...,
#         1.00000000e+00, 1.00000000e+00, 5.00000000e-01],
#        [9.99314599e-01, 0.00000000e+00, 4.34908997e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 5.00000000e-01],
#        [1.00000000e+00, 0.00000000e+00, 4.71175462e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 5.00000000e-01]])

# %%
#Transform the train and test set, and add on the id and sale price
data=x_train = pd.concat([df[['Id','SalePrice']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(df[feature_scale]),columns=feature_scale)],axis=1)

# %%
data.head()
# Out:
#    Id  SalePrice        Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# 0   1  12.247694  0.000000    0.235294     0.418208  0.366344     0.666667
# 1   2  12.109011  0.000685    0.000000     0.495064  0.391317     0.555556
# 2   3  12.317167  0.001371    0.235294     0.434909  0.422359     0.666667
# 3   4  11.849398  0.002056    0.294118     0.388581  0.390295     0.666667
# 4   5  12.429216  0.002742    0.235294     0.513123  0.468761     0.777778
#
#    OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0        0.500   0.036765      0.098361     0.12250    0.125089         0.0
# 1        0.875   0.227941      0.524590     0.00000    0.173281         0.0
# 2        0.500   0.051471      0.114754     0.10125    0.086109         0.0
# 3        0.500   0.669118      0.606557     0.00000    0.038271         0.0
# 4        0.500   0.058824      0.147541     0.21875    0.116052         0.0
#
# ...

# %% [markdown]
# # Feature Selection

# %%
## For feature selection 
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
data.head()
# Out:
#    Id  SalePrice        Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# 0   1  12.247694  0.000000    0.235294     0.418208  0.366344     0.666667
# 1   2  12.109011  0.000685    0.000000     0.495064  0.391317     0.555556
# 2   3  12.317167  0.001371    0.235294     0.434909  0.422359     0.666667
# 3   4  11.849398  0.002056    0.294118     0.388581  0.390295     0.666667
# 4   5  12.429216  0.002742    0.235294     0.513123  0.468761     0.777778
#
#    OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0        0.500   0.036765      0.098361     0.12250    0.125089         0.0
# 1        0.875   0.227941      0.524590     0.00000    0.173281         0.0
# 2        0.500   0.051471      0.114754     0.10125    0.086109         0.0
# 3        0.500   0.669118      0.606557     0.00000    0.038271         0.0
# 4        0.500   0.058824      0.147541     0.21875    0.116052         0.0
#
# ...

# %%
# Dependent variable
y_train = data[['SalePrice']]

# %%
# Drop dependent feature from data
x_train = data.drop(['Id','SalePrice'],axis=1)

# %%
x_train
# Out:
#       MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       0.235294     0.418208  0.366344     0.666667        0.500   0.036765
# 1       0.000000     0.495064  0.391317     0.555556        0.875   0.227941
# 2       0.235294     0.434909  0.422359     0.666667        0.500   0.051471
# 3       0.294118     0.388581  0.390295     0.666667        0.500   0.669118
# 4       0.235294     0.513123  0.468761     0.777778        0.500   0.058824
# ...          ...          ...       ...          ...          ...        ...
# 1455    0.235294     0.400718  0.353592     0.555556        0.500   0.058824
# 1456    0.000000     0.517503  0.453273     0.555556        0.625   0.235294
# 1457    0.294118     0.423859  0.379597     0.666667        1.000   0.507353
# 1458    0.000000     0.434909  0.393688     0.444444        0.625   0.441176
# 1459    0.000000     0.471175  0.398069     0.444444        0.625   0.316176
#
# ...

# %%
y_train
# Out:
#       SalePrice
# 0     12.247694
# 1     12.109011
# 2     12.317167
# 3     11.849398
# 4     12.429216
# ...         ...
# 1455  12.072541
# 1456  12.254863
# 1457  12.493130
# 1458  11.864462
# 1459  11.901583
#
# [1460 rows x 1 columns]

# %%
# Apply feature selection 
# First i specify lasso regression model and i select a suitble alpha.
# The bigger the alpha the less features that will selected
# Then i use the selectmodel object from sklearn,which
# will select the feature which coefficients are non-zero

feature_sel_model = SelectFromModel(Lasso(alpha=0.005,random_state=0))
feature_sel_model.fit(x_train,y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
feature_sel_model.get_support()
# Out:
# array([False, False, False,  True, False, False,  True, False, False,
#        False, False, False,  True, False, False,  True,  True, False,
#        False, False, False, False, False,  True, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False,  True, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False,  True, False, False,  True, False,  True,
#         True, False, False,  True,  True, False,  True, False, False,
#         True,  True, False, False,  True, False, False, False, False,
#        False])

# %%
selected_feature = x_train.columns[(feature_sel_model.get_support())]

print ('total feature: {}'.format((x_train.shape[1])))
print ('selected_feature: {}'.format(len(selected_feature)))
# Out:
# total feature: 82
# selected_feature: 20

# %%
selected_feature
# Out:
# Index(['OverallQual', 'YearRemodAdd', '1stFlrSF', 'GrLivArea', 'BsmtFullBath',
#        'Fireplaces', 'GarageCars', 'MSZoning_encoded', 'LotShape_encoded',
#        'BldgType_encoded', 'ExterQual_encoded', 'BsmtQual_encoded',
#        'BsmtExposure_encoded', 'BsmtFinType1_encoded', 'HeatingQC_encoded',
#        'CentralAir_encoded', 'KitchenQual_encoded', 'GarageType_encoded',
#        'GarageFinish_encoded', 'PavedDrive_encoded'],
#       dtype='object')

# %%
data_ready_for_model=x_train [selected_feature].head()

# %%
data_ready_for_model.head()
# Out:
#    OverallQual  YearRemodAdd  1stFlrSF  GrLivArea  BsmtFullBath  Fireplaces  \
# 0     0.666667      0.098361  0.356155   0.577712      0.333333    0.000000
# 1     0.555556      0.524590  0.503056   0.470245      0.000000    0.333333
# 2     0.666667      0.114754  0.383441   0.593095      0.333333    0.333333
# 3     0.666667      0.606557  0.399941   0.579157      0.333333    0.333333
# 4     0.777778      0.147541  0.466237   0.666523      0.333333    0.333333
#
#    GarageCars  MSZoning_encoded  LotShape_encoded  BldgType_encoded  \
# 0        0.50               0.5               1.0               0.0
# 1        0.50               0.5               1.0               0.0
# 2        0.50               0.5               0.0               0.0
# 3        0.75               0.5               0.0               0.0
# 4        0.75               0.5               0.0               0.0
#
#    ExterQual_encoded  BsmtQual_encoded  BsmtExposure_encoded  \
# ...
